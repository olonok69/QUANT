# %%
import backtrader as bt
import datetime
from backtrader_conners_rsi_strategy import ConnorsRSI

# %%
class MyStrategy(bt.Strategy):
    def __init__(self):
        self.myind = ConnorsRSI()

    def next(self):
        if self.myind.crsi[0] <= 10:
            self.buy()
        elif self.myind.crsi[0] >= 90:
            self.sell()

# %%
data = bt.feeds.YahooFinanceData(dataname='AAPL',
                                  fromdate=datetime.datetime(2017, 1, 1),
                                  todate=datetime.datetime(2017, 12, 31))

# %%
cerebro = bt.Cerebro()
cerebro.addstrategy(MyStrategy)
cerebro.broker.setcash(1337.0)
cerebro.broker.setcommission(commission=0.001)

# %%
cerebro.adddata(data)

# %%
print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())
# Out:
# Starting Portfolio Value: 1337.00

# %%
cerebro.run()

# %%
print('Ending Portfolio Value: %.2f' % cerebro.broker.getvalue())
# Out:
# Ending Portfolio Value: 1512.91

# %%
cerebro.plot(width=22,height=12)
# Out:
# <img src="data:image/png;base64,..." width="956">
# [[<Figure size 640x480 with 5 Axes>]]
