# %%
import backtrader as bt
import datetime
from backtrader_sma_strategy import SmaCross

# %%
cerebro = bt.Cerebro()
cerebro.broker.setcash(100000.0)

print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())

cerebro.run()

print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())
# Out:
# Starting Portfolio Value: 100000.00
# Final Portfolio Value: 100000.00

# %%
data = bt.feeds.YahooFinanceData(dataname='C',
                                  fromdate=datetime.datetime(2017, 1, 1),
                                  todate=datetime.datetime(2019, 12, 31))

# %%
cerebro = bt.Cerebro()
cerebro.addstrategy(SmaCross)
cerebro.broker.setcash(1337.0)
cerebro.broker.setcommission(commission=0.001)

# %%
cerebro.adddata(data)

# %%
print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())
# Out:
# Starting Portfolio Value: 1337.00

# %%
cerebro.run()

# %%
print('Ending Portfolio Value: %.2f' % cerebro.broker.getvalue())
# Out:
# Ending Portfolio Value: 1339.49

# %%
cerebro.plot(width=22,height=12)
# Out:
# <img src="data:image/png;base64,..." width="942">
# [[<Figure size 640x480 with 5 Axes>]]
